# %%
# Dependencies
from bs4 import BeautifulSoup
import requests
from splinter import Browser
import pymongo
import pandas as pd

# %%
# Set URL's
news_url= "https://mars.nasa.gov/news/"
img_url= "https://www.jpl.nasa.gov/spaceimages/?search=&category=Mars"
fact_url= "https://space-facts.com/mars/"
usgs_url= "https://astrogeology.usgs.gov/search/results?q=hemisphere+enhanced&k1=target&v1=Mars"

# %%
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
# Retrieve page with the browser module
browser.visit(news_url)

html = browser.html

soup = BeautifulSoup(html, 'html.parser')

# %%
# Create a variable to store the scraped article title and paragraph description
first_article = soup.find_all('div', class_='content_title')[1].text
first_para = soup.find_all('div', class_='article_teaser_body')[0].text
print(first_article)
print(first_para)
# Out:
# My Culture, My Voice
# In honor of Hispanic Heritage Month, Christina Hernandez, an instrument engineer on the Mars 2020 mission, talks about her childhood and journey to NASA.

# %%
# Retrieve page with the browser module
browser.visit(img_url)

# Click the Full Image link
browser.click_link_by_partial_text("FULL IMAGE")

# Click the more info link
browser.click_link_by_partial_text("more info")

# Get browser info into beautiful soup
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

image_url = soup.find(figure, class_='lede').a['href']
featured_image_url = f'https://www.jpl.nasa.gov/spaceimages/{image_url}'
print(featured_image_url)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-95-0f30507dbbf6> in <module>
#      12 soup = BeautifulSoup(html, 'html.parser')
#      13
# ---> 14 image_url = soup.find(figure, class_='lede').a['href']
#      15 featured_image_url = f'https://www.jpl.nasa.gov/spaceimages/{image_url}'
#      16 print(featured_image_url)
#
# NameError: name 'figure' is not defined

# %%
    browser.visit(img_url)
    browser.click_link_by_partial_text("FULL")
    page = requests.get(img_url)
    soup = BeautifulSoup(page.text, 'html.parser')

for link in soup.find_all('div'):
    featured_image_url = link.get('img src')
    
print(featured_image_url)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\selenium\webdriver\common\service.py in start(self)
#      75                                             stderr=self.log_file,
# ---> 76                                             stdin=PIPE)
#      77         except TypeError:
#
# ~\anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     799                                 errread, errwrite,
# --> 800                                 restore_signals, start_new_session)
#     801         except:
#
# ...

# %%
soup.find_all('div')
# Out:
# [<div id="main_container">
#  <div id="site_body">
#  <div class="site_header_area">
#  <header class="site_header">
#  <div class="brand_area">
#  <div class="brand1">
#  <a class="nasa_logo" href="http://www.nasa.gov" title="NASA">NASA</a>
#  </div>
#  <div class="brand2">
#  <div class="jpl_logo">
#  <a href="//www.jpl.nasa.gov/" id="jpl_logo" title="Jet Propulsion Laboratory">Jet Propulsion Laboratory</a>
#  </div>
#  <div class="caltech_logo">
#  <a href="http://www.caltech.edu/" id="caltech_logo" target="_blank" title="California Institute of Technology">California Institute of Technology</a>
#  </div>
#  </div>
#  <img alt="" class="print_only print_logo" src="/assets/images/logo_nasa_trio_black@2x.png"/>
#  </div>
#  <a class="visuallyhidden focusable" href="#main">Skip Navigation</a>
#  <div class="nav_area">
#  <a class="menu_button" href="javascript:void(0);" id="menu_button" title="menu button">
#  <span class="menu_icon">menu and search</span>
#  </a>
#  </div>
# ...
